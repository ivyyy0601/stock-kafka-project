# %%
# pip install s3fs

# %%
from kafka import KafkaConsumer
from time import sleep
from json import dumps,loads
import json

# %%
consumer = KafkaConsumer(
    'demo_test',
     bootstrap_servers=['{ip}:9092'], #add your IP here '13.221.117.93:9092'
    value_deserializer=lambda x: loads(x.decode('utf-8')))

# %%
# for c in consumer:
#     print(c.value)
#all the in producer

# %%
s3 = S3FileSystem()

# %%
for count, i in enumerate(consumer):
    with s3.open("s3://{kafka-stock-market-ivy}/stock_market_{}.json".format(count), 'w') as file: #this is the {the name of your s3}
        json.dump(i.value, file)
